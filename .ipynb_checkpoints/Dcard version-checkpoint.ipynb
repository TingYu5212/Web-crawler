# %%
# -*- coding: utf8 -*- 
import sys
import requests
import json
import os
import wget 
#取代違法字源的方法
def text_cleanup(text):
    new =""
    for i in text:
        if i not in'\?.!/;:"':
            new += i
    return new 
print("開始爬蟲") 
#偽裝成瀏覽器，(因為Dcard Server有用cloudflare來分流) 沒增加header user-agent 會直接503什麼鬼都看不到 
header = {
 
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36'
}
# 利用get取得API資料  
url = "https://www.dcard.tw/_api/forums/pet/posts?popular=true"
reqs = requests.get(url, headers=header)
#print(reqs.status_code) #503 錯誤 // 200等於正常 
if(int(reqs.status_code)==200):
    print("Dcard伺服器狀態:連線中")
else:
    print("Dcard伺服器狀態:拍謝失敗捏")
    os.system("pause")
    os._exit()

# %%
pip install fake-useragent
#with open("dataset-ptt-food-Content.txt","w",encoding="utf-8") as file:
 #       file.write(url+"\n")
#with open("dataset-ptt-food-Message.txt","w",encoding="utf-8") as file:
#        file.write(url+"\n")

# %%
import urllib.request as req
import sys
import os
from fake_useragent import UserAgent
import time
import requests

ua = UserAgent()
uaa = ua.random
chose_theme = str(input("請問您想選擇哪一版？"))
url="https://www.dcard.tw/f/"+chose_theme+"/?latest=true"
request=req.Request(url, headers={
    "User-Agent":"uaa"
})

resp = requests.get(url) #回傳為一個request.Response的物件
if(int(resp.status_code)==200):
    print("Dcard伺服器狀態:連線中")
else:
    print("Dcard伺服器狀態:拍謝失敗捏")
    os.system("pause")
    os._exit()

print(resp.text)

#with req.urlopen(request) as response:
#    data=response.read().decode("utf-8")
# Out:
# 請問您想選擇哪一版？makeup
# Dcard伺服器狀態:連線中
# <!DOCTYPE html><html lang="zh-Hant-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><title data-react-helmet="true">美妝板 | Dcard</title><meta data-react-helmet="true" property="og:image" content="https://www.dcard.tw/build/landing-c9e7b8fb.png"/><meta data-react-helmet="true" property="og:image:secure_url" content="https://www.dcard.tw/build/landing-c9e7b8fb.png"/><meta data-react-helmet="true" charSet="utf-8"/><meta data-react-helmet="true" http-equiv="X-UA-Compatible" content="IE=edge"/><meta data-react-helmet="true" name="application-name" content="Dcard"/><meta data-react-helmet="true" name="apple-itunes-app" content="app-id=951353454"/><meta data-react-helmet="true" name="theme-color" content="#006aa6"/><meta data-react-helmet="true" name="mobile-web-app-capable" content="yes"/><meta data-react-helmet="true" name="apple-mobile-web-app-capable" content="yes"/><meta data-react-helmet="true" property="fb:app_id" content="211628828926493"/><meta data-react-helmet="true" property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta data-react-helmet="true" property="al:ios:app_store_id" content="951353454"/><meta data-react-helmet="true" property="al:ios:app_name" content="Dcard"/><meta data-react-helmet="true" property="al:android:package" content="com.sparkslab.dcardreader"/><meta data-react-helmet="true" property="al:android:app_name" content="Dcard"/><meta data-react-helmet="true" property="og:type" content="website"/><meta data-react-helmet="true" property="og:site_name" content="Dcard"/><meta data-react-helmet="true" property="og:title" content="美妝板  | Dcard"/><meta data-react-helmet="true" property="og:url" content="https://www.dcard.tw/f/makeup/"/><meta data-react-helmet="true" name="description" content="不管你喜歡開架彩妝還是專櫃彩妝，美妝板提供各種最新彩妝開箱評比、粉底色號、唇膏試色、眼影試色、保養品推薦等你來討論！"/><meta data-react-helmet="true" property="og:description" content="不管你喜歡開架彩妝還是專櫃彩妝，美妝板提供各種最新彩妝開箱評比、粉底色號、唇膏試色、眼影試色、保養品推薦等你來討論！"/><meta data-react-helmet="true" property="al:ios:url" content="dcard://category/makeup/美妝/new"/><meta data-react-helmet="true" property="al:android:url" content="dcard://category/makeup/美妝/new"/><link data-react-helmet="true" rel="icon" sizes="32x32" type="image/png" href="/build/favicon_32-44259074.png"/><link data-react-helmet="true" rel="icon" sizes="72x72" type="image/png" href="/build/favicon_72-45b1e0ba.png"/><link data-react-helmet="true" rel="icon" sizes="512x512" type="image/png" href="/build/favicon_512-8aee0703.png"/><link data-react-helmet="true" rel="apple-touch-icon-precomposed" href="/build/favicon_144-79557003.png"/><link data-react-helmet="true" rel="apple-touch-icon-precomposed" href="/build/favicon_114-4a463b43.png"/><link data-react-helmet="true" rel="apple-touch-icon-precomposed" href="/build/favicon_72-45b1e0ba.png"/><link data-react-helmet="true" rel="apple-touch-icon-precomposed" href="/build/favicon_57-835f1693.png"/><link data-react-helmet="true" rel="canonical" href="https://www.dcard.tw/f/makeup/"/><link rel="preload" as="style" href="https://fonts.googleapis.com/css?family=Roboto:400,300"/><link rel="preload" as="style" href="/build/desktop-ccf6ffcd.css"/><link rel="preload" as="script" href="/build/vendor-68e528f6.js"/><link rel="preload" as="script" href="/build/desktop-fd216391.js"/><link rel="prefetch" as="script" href="/build/desktop-TopicPostListPage-b78f23a7.js"/><link rel="prefetch" as="script" href="/build/desktop-MyFollowingPage-da2267ae.js"/><link rel="prefetch" as="script" href="/build/desktop-MyTopicsPage-93620d46.js"/><link rel="prefetch" as="script" href="/build/desktop-CrossPostPage-883ad88a.js"/><link rel="prefetch" as="script" href="/build/desktop-DownloadAppPage-079e7b04.js"/><link rel="prefetch" as="script" href="/build/desktop-PostEditPage-8c4d99d1.js"/><link rel="prefetch" as="script" href="/build/desktop-FastpassPage-d44afa15.js"/><link rel="prefetch" as="script" href="/b ...
# /* sc-component-id: Icon__Main-lxtano-0 */
# .fiFQmV{position:relative;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;cursor:pointer;width:28px;height:28px;fill:#c4c4c4;} .fiFQmV img,.fiFQmV svg{width:100%;height:100%;} .fiFQmV:hover{fill:#3397cf;}.gKtWiP{position:relative;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;cursor:pointer;width:16px;height:16px;fill:#c4c4c4;} .gKtWiP img,.gKtWiP svg{width:100%;height:100%;}.kiLKUX{position:relative;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;cursor:pointer;width:16px;height:16px;fill:#c4c4c4;} .kiLKUX img,.kiLKUX svg{width:100%;height:100%;} .kiLKUX:hover{fill:#3397cf;}.erhgqM{position:relative;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;cursor:pointer;width:20px;height:20px;fill:#e1e1e1;} .erhgqM img,.erhgqM svg{width:100%;height:100%;} .erhgqM:hover{fill:#3397cf;}.fEeTTL{position:relative;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;cursor:pointer;width:28px;height:28px;fill:rgba(0,0,0,.6);} .fEeTTL img,.fEeTTL svg{width:100%;height:100%;}.iBHVMm{position:relative;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;cursor:pointer;width:20px;height:20px;fill:#c4c4c4;} .iBHVMm img,.iBHVMm svg{width:100%;height:100%;}.jLgpOH{position:relative;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;cursor:pointer;width:18px;height:18px;fill:#c4c4c4;} .jLgpOH img,.jLgpOH svg{width:100%;height:100%;}
# /* sc-component-id: ModeratorSidebar__BackgroundMask-sc-1uq5wpq-0 */
# .goxYye{background-color:rgba(0,0,0,0);pointer-events:none;position:fixed;left:0;right:0;top:0;bottom:0;z-index:100;width:100%;height:100%;-webkit-transition:background-color 0.1s ease-in;transition:background-color 0.1s ease-in;}
# /* sc-component-id: ModeratorSidebar__Sidebar-sc-1uq5wpq-1 */
# .kBUgAV{position:fixed;left:-280px;top:0;bottom:0;z-index:101;width:280px;height:100%;background-color:#ffffff;padding:24px 16px 0 24px;line-height:normal;overflow:scroll;-webkit-transition:left 0.1s ease-in;transition:left 0.1s ease-in;}
# /* sc-component-id: ModeratorSidebar__Header-sc-1uq5wpq-2 */
# .iZiNsQ{margin-bottom:28px;}
# /* sc-component-id: ModeratorSidebar__Section-sc-1uq5wpq-3 */
# .FZNnu{margin-bottom:24px;}.irSdiN{display:none;margin-bottom:24px;}
# /* sc-component-id: ModeratorSidebar__Title-sc-1uq5wpq-4 */
# .kSNGak{font-size:18px;font-weight:500;color:rgba(0,0,0,0.65);}
# /* sc-component-id: ModeratorSidebar__CloseBtn-sc-1uq5wpq-5 */
# .kUzObZ{float:right;top:-1.5px;}
# /* sc-component-id: ModeratorSidebar__SubTitle-sc-1uq5wpq-6 */
# .kpxZmt{font-size:14px;font-weight:500;color:rgba(0,0,0,0.45);margin-bottom:8px;}
# /* sc-component-id: ModeratorSidebar__ItemContainer-sc-1uq5wpq-7 */
# .gbbbHS{height:44px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;} .gbbbHS:hover{background-color:rgba(0,0,0,0.07);border-radius:4px;margin:0 -10px;padding:0 10px;}
# /* sc-component-id: ModeratorSidebar__ItemText-sc-1uq5wpq-8 */
# .aWpVu{font-size:16px;font-weight:500;color:rgba(0,0,0,0.65);margin-left:12px;}.duBezB{font-size:14px;font-weight:500;color:rgba(0,0,0,0.65);margin-left:12px;}
# /* sc-component-id: Carousel__Main-sc-1ec7a7k-2 */
# .etqVk{position:relative;} .etqVk:hover .Carousel__LeftArrow-sc-1ec7a7k-0,.etqVk:hover .Carousel__RightArrow-sc-1ec7a7k-1{opacity:1;}
# /* sc-component-id: ForumBanner__Main-sc-544o16-0 */
# .cTabwy{position:relative;background-color:#d8d8d8;} .cTabwy >:first-child{position:relative;z-index:1;}
# /* sc-component-id: ForumBanner__Slide-sc-544o16-1 */
# .hfTHka{width:720px;height:240px;} .hfTHka a{overflow:hidden;display:block;width:100%;height:100%;background-size:cover;background-position:center center;} .hfTHka span{position:absolute;left:-9999px;}
# /* sc-component-id: ForumBanner__HeroImage-sc-544o16-2 */
# .jlGZky{width:100%;}
# /* sc-component-id: ForumAvatar__Main-miynwg-0 */
# .cKMVxK{height:40px;width:40px;border-radius:50%;background-color:lightgray;background-image:url(https://megapx-stage-assets.dcard.io/images/9fb1e631-b6cf-4bbc-be70-b2039bc4f28c/full.jpeg);background-size:cover;background-position:center;background-repeat:no-repeat;}.kqzcrk{height:20px;width:20px;border-radius:50%;background-color:lightgray;background-image:url(https://megapx-stage-assets.dcard.io/images/9fb1e631-b6cf-4bbc-be70-b2039bc4f28c/full.jpeg);background-size:cover;background-position:center;background-repeat:no-repeat;}
# /* sc-component-id: PostListHeader__StyledForumBanner-aa5hy3-9 */
# .gNORaR{margin-bottom:80px;}
# /* sc-component-id: PostListHeader__Title-aa5hy3-10 */
# .fkQyKa{font-size:30px;font-weight:500;line-height:1.33;color:#000000;margin:0 0 0 10px;}
# /* sc-component-id: PostListHeader__TabBlock-aa5hy3-11 */
# .cBSLZi{margin-right:0;margin-left:auto;height:100%;font-size:16px;} .cBSLZi a{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 16px;margin-right:20px;} .cBSLZi a:last-child{margin-right:0;}
# /* sc-component-id: More__Main-sc-11f2yyv-0 */
# .cvKfTt{position:absolute;top:24px;right:0;z-index:10;}
# /* sc-component-id: Image__Wrapper-sc-1wea68w-0 */
# .jclNmK{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://imgur.dcard.tw/rHwXbzst.jpg);}.kIcyRM{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://imgur.dcard.tw/0PB5ssRt.jpg);}.kChrkq{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://imgur.dcard.tw/TnQrmWwt.jpg);}.bvRuoB{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://megapx-assets.dcard.tw/images/5e778574-da4e-42f3-adda-0dee754ebca8/1280.jpeg);}.ctfnvK{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://imgur.dcard.tw/UMiay3Ut.jpg);}.iTIcuP{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://megapx-assets.dcard.tw/images/9a0044b9-9486-45a7-8d1e-bd3b7ba37706/full.jpeg);}.juWLsj{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://megapx-assets.dcard.tw/images/db0f40c0-b2bc-4ea9-b706-929e8e0151ed/1280.jpeg);}.fXWRSc{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://imgur.dcard.tw/heBKrMxt.jpg);}.gjjMrX{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://megapx-assets.dcard.tw/images/454b2cc6-6d4c-481b-a5e7-68cc8def8cf4/1280.jpeg);}.ggNoGz{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://imgur.dcard.tw/cb0igMft.jpg);}.fICaTA{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://megapx-assets.dcard.tw/images/75dc277f-b5c6-4ec4-99fd-b10087442c8e/1280.jpeg);}.lotsib{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://megapx-assets.dcard.tw/images/960e7090-a9d5-4578-9a8e-a36d6d174146/full.jpeg);}.ktcJdd{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://megapx-assets.dcard.tw/images/a4dd9bf1-5bf5-4f86-b539-bdf8e1b92dbb/1280.jpeg);}.eGHCiB{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://imgur.dcard.tw/2FCrJNHt.jpg);}.cMqCbZ{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://megapx-assets.dcard.tw/images/f052aa9a-578e-4eba-b4fe-be13319a263b/1280.jpeg);}.gLHNIf{margin-left:36px;width:84px;height:84px;border:1px solid #dedede;background-repeat:no-repeat;background-position:center;background-size:cover;border-radius:4px;background-image:url(https://megapx ...
# /* sc-component-id: Image__VideoIcon-sc-1wea68w-1 */
# .icRTvG{margin:56px 56px;width:20px;height:20px;background-image:url(../../../images/list_icon_video.svg);background-repeat:no-repeat;background-position:center;background-size:cover;}
# /* sc-component-id: Title__Text-v196i6-0 */
# .gmfDU{font-size:18px;font-weight:bold;margin:0;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;opacity:.85;}
# /* sc-component-id: Header__Container-xvcbwe-0 */
# .kJGVah{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:20px;max-width:500px;overflow:hidden;}
# /* sc-component-id: Header__Author-xvcbwe-1 */
# .GahET{-webkit-flex:0 1 auto;-ms-flex:0 1 auto;flex:0 1 auto;min-width:0;}
# /* sc-component-id: Header__PublishedDateTime-xvcbwe-3 */
# .MDszy{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;opacity:.35;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;} .MDszy:before{content:'．';}
# /* sc-component-id: Reactions__Wrapper-sc-1222jb7-0 */
# .epiqTA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: Reactions__ReactionList-sc-1222jb7-1 */
# .Esxcw{width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;margin-right:8px;}
# /* sc-component-id: Reactions__UnActivedHeart-sc-1222jb7-4 */
# .iyEkog{width:15px;height:15px;background-size:15px;background-image:url(/build/ic_like_unActived-cce62ada.png);background-repeat:no-repeat;margin:2px 0 0 2px;}
# /* sc-component-id: ActionBar__CollectText-pwz3il-0 */
# .bDBQWT{padding-top:2px;}
# /* sc-component-id: ActionBar__LikeCount-pwz3il-1 */
# .cGEHtj{padding-top:2px;color:rgba(0,0,0,0.45);}
# /* sc-component-id: ActionBar__Container-pwz3il-2 */
# .cVvrOe{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-top:18px;color:rgba(0,0,0,0.35);}
# /* sc-component-id: ActionBar__ReactionsWrapper-pwz3il-3 */
# .jJLOqN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;opacity:.75;padding-top:4px;color:rgba(0,0,0,0.45);}
# /* sc-component-id: ActionBar__CollectButton-pwz3il-4 */
# .iwpawx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:16px;cursor:pointer;line-height:24px;}
# /* sc-component-id: ActionBar__CommentWrapper-pwz3il-5 */
# .hkpJwJ{opacity:0.93;font-size:14px;line-height:24px;margin:2px 0 0 18px;}
# /* sc-component-id: ActionBar__CommentText-pwz3il-6 */
# .dvLqxs{margin-right:6px;}
# /* sc-component-id: NormalPostLayout__Wrapper-sc-1kpmwi8-0 */
# .fIrnKP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: NormalPostLayout__Left-sc-1kpmwi8-1 */
# .kKMUkE{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:hidden;min-width:0;max-width:480px;}
# /* sc-component-id: NormalPostLayout__Right-sc-1kpmwi8-2 */
# .bOulQo{-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;}
# /* sc-component-id: NormalPostLayout__HeaderWrapper-sc-1kpmwi8-3 */
# .hhDOwA{margin-bottom:12px;}
# /* sc-component-id: NormalPostLayout__TitleWrapper-sc-1kpmwi8-4 */
# .eSrfAB{padding-bottom:8px;}
# /* sc-component-id: PostPages__Main-sc-1cz8fxj-0 */
# .Fyicu{background-color:#fafafa;border-radius:4px;padding-top:0;overflow:hidden;}
# /* sc-component-id: ForumInfo__Main-sc-1rv7epg-0 */
# .ftMAdo{width:300px;background-color:#fff;border-radius:2px;padding:20px;line-height:1.57;color:rgba(0,0,0,.6);}
# /* sc-component-id: ForumInfo__Header-sc-1rv7epg-1 */
# .XmxRH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: ForumInfo__Title-sc-1rv7epg-2 */
# .fmBCcp{margin:0 0 0 10px;font-size:20px;font-weight:500;color:#000000;line-height:1.6;}
# /* sc-component-id: ForumInfo__Info-sc-1rv7epg-3 */
# .dzWFnD{margin-top:4px;}
# /* sc-component-id: ForumInfo__DescriptionBlock-sc-1rv7epg-4 */
# .lkFboE{padding-right:16px;position:relative;-webkit-transition:height .3s;transition:height .3s;height:22px;overflow:hidden;}
# /* sc-component-id: ForumInfo__Description-sc-1rv7epg-5 */
# .fFKbXX{position:relative;line-height:22px;}
# /* sc-component-id: sc-bwzfXH */
# .hMglYk{position:absolute;top:0;width:100%;background-color:#fff;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-htpNat */
# .dppVRn{position:absolute;top:-3px;right:-6px;-webkit-transition:-webkit-transform .3s;-webkit-transition:transform .3s;transition:transform .3s;}
# /* sc-component-id: ForumInfo__TopicBlock-sc-1rv7epg-6 */
# .hdFnIu{margin-top:16px;}
# /* sc-component-id: ForumInfo__ActionBlock-sc-1rv7epg-7 */
# .lkfIxm{margin-top:16px;}
# /* sc-component-id: sc-bxivhb */
# .eGxnNJ{width:100%;color:#3397cf;border:1px solid #3397cf;}
# /* sc-component-id: ForumInfo__ButtonContent-sc-1rv7epg-8 */
# .bxkpeP{position:relative;line-height:1.57;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;margin:auto;}
# /* sc-component-id: sc-ifAKCX */
# .cqQRKG{fill:#3397cf;position:absolute;left:calc(-20px - 4px);}
# /* sc-component-id: sc-EHOje */
# .hXSFXX{fill:#fff;position:absolute;left:calc(-20px - 4px);top:1px;}
# /* sc-component-id: sc-bZQynM */
# .eoiagX{margin-top:10px;width:100%;color:#fff;}</style><script></script></head><body><noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-TWLTW4M" height="0" width="0" style="display:none"></iframe></noscript><noscript><img src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=gj89j1a8Dy000J" style="display:none" height="1" width="1" alt=""/></noscript><div id="root"><div data-reactroot=""><header class="Header_header_gbQ7gR"><div class="Header_wrapper_2hNvEY"><a class="Header_logo_xcQiO6" href="/"></a><div class="Header_search_2lM7zd"><form class="HeaderSearchForm_form_2xQmyq" id="search"><input type="hidden" name="forum" value="makeup"/><input type="search" name="query" value="" class="HeaderSearchForm_input_35r7qv" placeholder="搜尋美妝板、看板、人物"/><button class="HeaderSearchForm_button_2vqtAe" type="submit"><span class="HeaderSearchForm_img_3knwd2"></span></button></form></div><nav class="Header_nav_1dGgoO"><a class="Header_navLink_2SbOPB" href="/signup"><span class="Header_navText_1m5321"><span>登入</span></span></a><div class="HeaderDropdownMenu_moreDropdown_2yGVX8"><div class="DropdownMenu_container_1gb-yu"><div><div data-tip="true" data-for=""><div class="HeaderDropdownMenu_trigger_1WYUU9"><div class="HeaderDropdownMenu_triangle_2tZI3-"></div></div><div class=""><div class="__react_component_tooltip place-top type-dark " id="" data-id="tooltip"><span>更多</span></div></div></div></div></div></div></nav></div></header><div class="App_main_38MbtT"><div class="ForumListPage_body_2FYgZL"><div class="ForumListPage_page_2ozpK7"><div class="ForumListPage_forumList_3UTB13"><ul class="ForumList_list_3jlAjS"><li class="ForumEntryGroup_group_1WhBu8 ForumEntryGroup_groupExpanded_OQm_Wh"><a class="ForumEntryGroup_title_2woFUO ForumEntryGroup_titleExpanded_3dSOIt"><strong>看板列表</strong></a><div class="ForumEntryGroup_listWrapper_3RXtl4"><div class="ForumEntryGroup_listContainer_1FdKZt"><div class="ForumEntryGroup_listContainerInner_2ZSHKa"><ul class="ForumEntryGroup_list_cdSR2f"><li><a class="ForumEntry_link_3tNC45" href="/f">全部</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/2019_ncov">武漢肺炎</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/youtuber">YouTuber</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/announcement">官方公告</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/smallgoodthings">小事公益</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/freshman">新生季</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_linkActive_3Zi3ce ForumEntry_unRead_1ptlOL" href="/f/makeup">美妝</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/manicure">美甲</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/facelift">醫美</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/fragrance">香氛</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/hairsalon">美髮</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/orthodontics">牙齒矯正</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/contact_lens">隱形眼鏡</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/dressup">穿搭</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/sneakers">球鞋</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/buyonline">網路購物</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/boutique">精品</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/relationship">感情</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/mood">心情</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/talk">閒聊</a></li><li><a class="ForumEntry_link_3tNC45 ForumEntry_unRead_1ptlOL" href="/f/funny">有趣</a></li>< ...

# %%
import requests
import bs4
import time
import gettext
from lxml import etree
import re
get_all_href(url)
# Out:
# None

# %%
def get_all_href(url):
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, "lxml")
    dcard_title = soup.find_all('h3', re.compile('PostEntry_title_'))
    #print（'Dcard熱門前十文章標題：'）
    for item in dcard_title:
        print(item+"\n")

# %%
r = requests.get(url)
soup = bs4.BeautifulSoup(r.text, "lxml")
@@dcard_title = soup.find_all('h3', re.compile('PostEntry_title_'))

for item in dcard_title:
    print(item+"\n")
# Out:
# []

# %%
def get_all_href(url):
   # r = requests.get(url,verify="D:\GitHub\ptt\certs.pem")
    soup = bs4.BeautifulSoup(r.text, "lxml")
    results = soup.select("div.title")
    for item in results:
        a_item = item.select_one("a")
        if a_item:
            get_article_content(article_url='https://www.ptt.cc'+a_item.get('href'))

# %%
def get_article_content(article_url):
    r = requests.get(article_url)
    soup = bs4.BeautifulSoup(r.text, "lxml")
    with open("dataset-ptt-food-Contentf.txt","a+",encoding="utf-8") as file:
         file.write("\n------------------ 下一篇 ------------------\n")
    with open("dataset-ptt-food-Messagef.txt","a+",encoding="utf-8") as file:
         file.write("\n------------------ 下一篇 ------------------\n")
    results = soup.select('span.article-meta-value')
    if results:
        try:
            print('作者:', results[0].text)
            print('看板:', results[1].text)
            print('標題:', results[2].text)
            print('時間:', results[3].text)        
            with open("dataset-ptt-food-Contentf.txt","a+",encoding="utf-8") as file:
                 file.write("作者:")
                 file.write(results[0].text+"\n")
                 file.write("標題:")
                 file.write(results[2].text+"\n") 
                 file.write("時間:")
                 file.write(results[3].text+"\n")
            with open("dataset-ptt-food-Messagef.txt","a+",encoding="utf-8") as file:
                 file.write("作者:")
                 file.write(results[0].text+"\n")
                 file.write("標題:")
                 file.write(results[2].text+"\n") 
                 file.write("時間:")
                 file.write(results[3].text+"\n")
        except IndexError:
            print(r)
            with open("dataset-ptt-food-Contentf.txt","a+",encoding="utf-8") as file:
                 file.write("作者:")
                 file.write(results[0].text+"\n")
                 file.write("標題:")
                 file.write(results[1].text+"\n") 
                 file.write("時間:")
                 file.write(results[2].text+"\n")
            with open("dataset-ptt-food-Messagef.txt","a+",encoding="utf-8") as file:
                 file.write("作者:")
                 file.write(results[0].text+"\n")
                 file.write("標題:")
                 file.write(results[1].text+"\n") 
                 file.write("時間:")
                 file.write(results[2].text+"\n")
            
    html = requests.get(article_url).content.decode('utf-8')
    selector = etree.HTML(html)
    contextlist = selector.xpath("//*[@id='main-content']/text()")
    contextlist = [x.strip() for x in contextlist if x.strip() != '']
    with open("dataset-ptt-food-Contentf.txt","a+",encoding="utf-8") as file:    
        file.write("\n------------------ Content ------------------\n")
    fileObject = open("dataset-ptt-food-Contentf.txt","a+",encoding="utf-8")
    for context in contextlist:
        fileObject.write(context)
    print(contextlist)
    with open("dataset-ptt-food-Messagef.txt","a+",encoding="utf-8") as file:     
        file.write("\n------------------ Message ------------------\n") 
    for tag in soup.select('div.push'):
        push_tag = tag.find("span", {'class': 'push-tag'}).text
        push_userid = tag.find("span", {'class': 'push-userid'}).text    
        push_content = tag.find("span", {'class': 'push-content'}).getText().replace(':','').strip()
        print (push_tag,"留言者:",push_userid,"留言:",push_content)
        with open("dataset-ptt-food-Messagef.txt","a+",encoding="utf-8") as file:     
             file.write(push_tag)
             file.write(push_userid)
             file.write(push_content+"\n")         
    print("------------------ 下一篇 ------------------\n")
    time.sleep(5)

# %%
# 載入使用的套件
import pandas as pd
import requests
from requests_html import HTML
import re


# 檢視資料結構
ID = '231030181'
url = 'https://www.dcard.tw/_api/posts/' + ID
# 透過request套件抓下這個網址的資料
requ = requests.get(url)
# 初步檢視抓到的資料結構
requ.json()

# 將抓下來的資料轉為DataFrame
ID = '231030181'
url = url = 'https://www.dcard.tw/_api/posts/' + ID
requ = requests.get(url)
rejs = requ.json()
pd.DataFrame(
    data=
    [{'ID':rejs['id'],
      'title':rejs['title'],
      'content':rejs['content'],
      'excerpt':rejs['excerpt'],
      'createdAt':rejs['createdAt'],
      'updatedAt':rejs['updatedAt'],
      'commentCount':rejs['commentCount'],
      'forumName':rejs['forumName'],
      'forumAlias':rejs['forumAlias'],
      'gender':rejs['gender'],
      'likeCount':rejs['likeCount'],
      'reactions':rejs['reactions'],
      'topics':rejs['topics']}],
    columns=['ID','title','content','excerpt','createdAt','updatedAt','commentCount','forumName','forumAlias','gender','likeCount','reactions','topics'])

# 撰寫簡單的函數，透過輸入文章ID，就輸出文章的資料
def Crawl(ID):
    link = 'https://www.dcard.tw/_api/posts/' + str(ID)
    requ = requests.get(link)
    rejs = requ.json()
    return(pd.DataFrame(
        data=
        [{'ID':rejs['id'],
          'title':rejs['title'],
          'content':rejs['content'],
          'excerpt':rejs['excerpt'],
          'createdAt':rejs['createdAt'],
          'updatedAt':rejs['updatedAt'],
          'commentCount':rejs['commentCount'],
          'forumName':rejs['forumName'],
          'forumAlias':rejs['forumAlias'],
          'gender':rejs['gender'],
          'likeCount':rejs['likeCount'],
          'reactions':rejs['reactions'],
          'topics':rejs['topics']}],
        columns=['ID','title','content','excerpt','createdAt','updatedAt','commentCount','forumName','forumAlias','gender','likeCount','reactions','topics']))

# 嘗試使用撰寫出的函數，抓取編號231030181的文章
Crawl(231030181)

# 一次讀取100篇最熱門的文章
url = 'https://www.dcard.tw/_api/posts?popular=true&limit=100'
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
for i in range(len(rejs)):
    df = df.append(Crawl(rejs[i]['id']),ignore_index=True)
print(df.shape)
df

# 透過迴圈讀取10*100篇文章，若需讀取更多資料，可以將range(10)中的數值提升
for j in range(10):
    last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID
    url = 'https://www.dcard.tw/_api/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Crawl(rejs[i]['id']), ignore_index=True)
print(df.shape)
df

# 將資料存到桌面
df.to_excel('C:/Users/TLYu0419/Desktop/Dcard.xlsx')
